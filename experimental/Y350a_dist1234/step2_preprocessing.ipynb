# %% [markdown]
# # Step 2. Preprocessing: remove outliers and normalise intensities
#
# Raw detector counts contain **zingers** (cosmic-ray hot pixels) and intensity drift between
# distances caused by different flux levels at each zone-plate position.
# This step produces the cleaned, flat-field-corrected datasets `/exchange/pdata{k}` and the
# reference `/exchange/pref` that are used by all downstream steps.

# %%
import numpy as np
import cupy as cp
import h5py
import matplotlib.pyplot as plt
import cupyx.scipy.ndimage as ndimage
from holotomocupy.utils import *

# %% [markdown]
# ## Init

# %%
ntheta = 4500
ids = np.arange(0, 4500, 4500 / ntheta).astype('int')

z1_ids = np.array([0, 1, 2, 3])
str_z1_ids = ''.join(map(str, z1_ids + 1))
ndist = len(z1_ids)

path_out = '/data2/vnikitin/brain_rec/20251115/Y350a'
file_out = f'data{str_z1_ids}.h5'

with h5py.File(f'{path_out}/{file_out}') as fid:
    detector_pixelsize      = fid['/exchange/detector_pixelsize'][0]
    focustodetectordistance = fid['/exchange/focusdetectordistance'][0]
    z1                      = fid['/exchange/z1'][:]
    shifts                  = fid['/exchange/shifts'][ids]
    attrs                   = fid['/exchange/attrs'][ids]
    shape                   = np.array(fid[f'/exchange/data0'].shape)
    shape_ref               = fid['/exchange/data_white_start0'].shape
    shape_dark              = fid['/exchange/data_dark0'].shape

n     = shape[1]
ndark = shape_dark[0]
nref  = shape_ref[0]

print(f'{z1=}')
print(f'{focustodetectordistance=}')
print(f'{detector_pixelsize=}')

# %% [markdown]
# ### Outlier (zinger) removal
#
# Cosmic-ray hits produce isolated pixels with extreme counts.
# `remove_outliers` applies a GPU median filter of size `radius × radius` and replaces any pixel
# that deviates from the filtered value by more than `threshold × filtered_value` with the
# median-filtered estimate.

# %%
def remove_outliers(data, radius, threshold):
    """Remove zingers on a batch of GPU images using a 3-D median filter.

    Applies an independent [radius × radius] 2-D median filter to each slice
    along axis 0 (no mixing across projections).

    Parameters
    ----------
    data      : cupy ndarray [N, H, W], float32 — already on GPU
    radius    : int   — filter window size (radius × radius pixels)
    threshold : float — flag pixel as outlier if |pixel - median| > threshold × median

    Returns
    -------
    cupy ndarray [N, H, W], float32
    """
    fdata = ndimage.median_filter(data, size=(1, radius, radius))
    mask  = cp.abs(data - fdata) > fdata * threshold
    return cp.where(mask, fdata, data)

# %% [markdown]
# ### Read ref and dark

# %%
ref0 = np.empty([nref,ndist,n,n],dtype='float32')
ref1 = np.empty([nref,ndist,n,n],dtype='float32')
dark = np.empty([ndark,ndist,n,n],dtype='float32')
with h5py.File(f'{path_out}/{file_out}') as fid:
    for k in range(ndist):
        ref0[:,k] = fid[f'/exchange/data_white_start{k}'][:]
        ref1[:,k] = fid[f'/exchange/data_white_end{k}'][:]
        dark[:,k] = fid[f'/exchange/data_dark{k}'][:]

# %% [markdown]
# ### Remove outliers

# %%
dark = np.mean(dark, axis=0).astype('float32')  # [ndist, n, n]
ref  = np.mean(ref0, axis=0).astype('float32')  # [ndist, n, n]  (use start refs)

radius    = 3
threshold = 0.9

# Process entirely on GPU: subtract dark, clip negatives, remove outliers
ref_gpu  = cp.array(ref) - cp.array(dark)
ref_gpu[ref_gpu < 0] = 0
ref_gpu[:] = remove_outliers(ref_gpu, radius, threshold)
ref = ref_gpu.get()

# %% [markdown]
# #### Intensity normalisation across distances
#
# Each distance is illuminated at a slightly different flux level because the zone-plate changes
# its position along the optical axis.  We scale all distances to match the mean counts of
# distance 0 so that the multi-distance data can later be compared on an equal footing:
#
# 1. Compute mean reference counts `mmr[k]` for each distance.
# 2. Scale projections and reference by `mmr[0] / mmr[k]`.
# 3. Divide by `mmr[0]` so that the final reference has unit mean.

# %%
dark_gpu = cp.array(dark)   # [ndist, n, n] — cached on GPU for the main loop

# Process the first projection of each distance to establish the target mean.
# The main loop will normalise every projection to this value.
mean_data_ref = np.zeros(ndist, dtype='float32')
with h5py.File(f'{path_out}/{file_out}') as fid:
    for k in range(ndist):
        data = cp.array(fid[f'/exchange/data{k}'][ids[0]].astype('float32'))
        data -= dark_gpu[k]
        data[data < 0] = 0
        data = remove_outliers(data[None], radius, threshold)[0]
        mean_data_ref[k] = float(data.mean())

# %%
mmr = np.mean(ref,axis=(1,2))
print(mmr)
print(mmr[0]/mmr[:])
print(mean_data_ref)
print(mean_data_ref/mmr)
print(mean_data_ref[0]/mean_data_ref)
print(mean_data_ref*mmr[0]/mmr[:]/mmr[0])

# %%
### counts before scan
mmr = np.mean(ref,axis=(1,2))
# scale mean of first projection based on that
mean_data_ref *= mmr[0]/mmr[:]
# scale ref based on that
ref *= mmr[0]/mmr[:,None,None]

mean_data_ref/=mmr[0]
ref/=mmr[0]

# ref /= mean_data_ref[:,None,None]
print(np.mean(ref,axis=(1,2)))

# %%
with h5py.File(f'{path_out}/{file_out}','a') as fid:    
    if f'/exchange/pref' in fid:
        del fid[f'/exchange/pref']
    fid.create_dataset(f'/exchange/pref', data=ref)

# %% [markdown]
# ### Process and save all projections
#
# For every projection angle and distance: subtract dark, clip negatives, remove zingers, normalise
# by the mean count, and write to `/exchange/pdata{k}`.

# %%
chunk_size = 16   # projections read from HDF5 and processed per GPU batch

with h5py.File(f'{path_out}/{file_out}', 'a') as fid:
    for k in range(ndist):
        if f'/exchange/pdata{k}' in fid:
            del fid[f'/exchange/pdata{k}']
        data_out = fid.create_dataset(f'/exchange/pdata{k}', shape=shape)

        for j in range(0, ntheta, chunk_size):
            end = min(j + chunk_size, ntheta)

            # One HDF5 call reads the whole chunk → GPU in one transfer
            data = cp.array(fid[f'/exchange/data{k}'][ids[j:end]].astype('float32'))
            data -= dark_gpu[k]
            data[data < 0] = 0
            data[:] = remove_outliers(data, radius, threshold)

            # Normalise each projection to the target mean (vectorised over chunk)
            data *= mean_data_ref[k] / data.mean(axis=(1, 2), keepdims=True)

            # One write call stores the whole chunk
            data_out[j:end] = data.get()

            if j % 100 == 0:
                print(j, k, float(data[0].mean()))
