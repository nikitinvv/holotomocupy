# %% [markdown]
# # Step 3. Combine multi-source shifts into a single calibrated shift file
#
# Four independent sources of sample displacement are measured separately and then summed to produce
# the final per-projection, per-distance shift field used in Steps 4 and 5:
#
# | Source | Variable | Description |
# |--------|----------|-------------|
# | Encoder readback | `random_shifts` | Sample stage jitter reported by the scan motor (`correct.txt`) |
# | RHAPP inter-plane | `rhapp_shifts` | Lateral offset *between* distance planes from Peter's MATLAB alignment |
# | Motion correction | `motion_shifts` | Slow drift of the reference plane over the full 360° scan |
# | 3-D tomo correction | `correct3d_shifts` | Residual shifts after a preliminary tomographic reconstruction |
#
# All shifts are converted to **object pixels at the highest magnification** (distance 0) before
# summation.

# %%
import os
import numpy as np
import h5py
import matplotlib.pyplot as plt
from holotomocupy.utils import *

# %% [markdown]
# ## Init

# %%
ref_dist = 2  # reference distance index for motion correction

path     = '/data3/vnikitin/brain/20251115/Y350a_new/'
path_out = '/data3/vnikitin/brain/20251115/Y350a_new_rec'
pfile    = 'Y350a_HT_20nm_8dist'
fpath    = f'{path_out}/{pfile}.h5'

with h5py.File(fpath) as fid:
    detector_pixelsize      = fid['/exchange/detector_pixelsize'][0]
    focustodetectordistance = fid['/exchange/focusdetectordistance'][0]
    z1                      = fid['/exchange/z1'][:]
    energy                  = fid['/exchange/energy'][0]
    shifts                  = fid['/exchange/shifts'][:]
    shape                   = np.array(fid['/exchange/data0'].shape)

ntheta = shape[0]
n      = shape[1]
ndist  = len(z1)

wavelength          = 1.24e-09 / energy
z2                  = focustodetectordistance - z1
magnifications      = focustodetectordistance / z1
norm_magnifications = magnifications / magnifications[0]
distances           = (z1 * z2) / focustodetectordistance * norm_magnifications**2
voxelsize           = detector_pixelsize / magnifications[0]

print(f'{energy=}')
print(f'{z1=}')
print(f'{focustodetectordistance=}')
print(f'{detector_pixelsize=}')
print(f'{magnifications=}')
print(f'{voxelsize=}')
print(f'{distances=}')
# Out:
# energy=np.float32(17.1)
# z1=array([0.008245, 0.008599, 0.010014, 0.012952], dtype=float32)
# focustodetectordistance=np.float32(1.217)
# detector_pixelsize=np.float32(2.9520295e-06)
# magnifications=array([147.60461 , 141.52809 , 121.529854,  93.962326], dtype=float32)
# voxelsize=np.float32(1.9999575e-08)
# distances=array([0.00818914, 0.00784971, 0.00673264, 0.00519275], dtype=float32)

# %% [markdown]
# ### Convert encoder shifts to object-pixel coordinates
#
# The motor encoder reports shifts in physical units for the *detector* plane.  Dividing by
# `norm_magnifications[k]` maps each distance to the object plane at the highest magnification
# (distance 0).  The (row, col) convention is also swapped here from (y, x) → (x, y).

# %%
random_shifts = np.empty([ntheta, ndist, 2], dtype='float32')
random_shifts[..., 0] = shifts[..., 1] / norm_magnifications
random_shifts[..., 1] = shifts[..., 0] / norm_magnifications

# %% [markdown]
# #### RHAPP inter-plane alignment (from Peter's MATLAB pipeline)
#
# `rhapp_python{str_z1_ids}.mat` contains the lateral offsets between the distance planes computed
# by the RHAPP algorithm.  The axes are permuted and sign-flipped to match the Python (row, col)
# convention used here.

# %%
def _load_octave_text_mat(fpath, varname):
    with open(fpath, 'r') as _f:
        lines = _f.read().splitlines()
    i = 0
    while i < len(lines):
        if lines[i].strip() == f'# name: {varname}':
            i += 1
            meta = {}
            while i < len(lines) and lines[i].startswith('#'):
                parts = lines[i][1:].strip().split(':', 1)
                if len(parts) == 2:
                    meta[parts[0].strip()] = parts[1].strip()
                i += 1
            if 'ndims' in meta:
                shape = tuple(int(x) for x in lines[i].split()); i += 1
                nn = 1
                for s in shape: nn *= s
                vals = []
                while len(vals) < nn:
                    vals.extend(lines[i].split()); i += 1
                return np.array(vals, dtype='float64').reshape(shape, order='F')
            else:
                rows = int(meta.get('rows', 1))
                cols = int(meta.get('columns', 1))
                vals = []
                for _ in range(rows):
                    vals.extend(lines[i].split()); i += 1
                return np.array(vals, dtype='float64').reshape(rows, cols)
        i += 1
    raise KeyError(f'{varname!r} not found in {fpath}')

_rhapp_path = f'{path}/{pfile}_/rhapp.mat'
rhapp_raw   = _load_octave_text_mat(_rhapp_path, 'rhapp')
rhapp_shifts = (-rhapp_raw.swapaxes(0, 2)[:ntheta]).astype('float32')

# %% [markdown]
# ### Motion shifts — slow drift of the reference plane
#
# `correct_motion.txt` gives the stage position as a function of angle for a single reference
# distance (index 2 here).  The **random_shifts at that distance are subtracted** so that only the
# slow drift component remains, which is then replicated to all four distances.

# %%
_motion_path = f'{path}/{pfile}_{ref_dist+1}_/correct_motion.txt'
raw_motion    = np.loadtxt(_motion_path)[:ntheta, ::-1].astype('float32')
motion_base   = raw_motion / norm_magnifications[ref_dist] - random_shifts[:, ref_dist]
motion_shifts = np.tile(motion_base[:, np.newaxis], (1, ndist, 1))

# %% [markdown]
# ### 3-D tomographic correction shifts
#
# After an initial tomographic reconstruction, any remaining systematic misalignment of projections
# shows up as blurring.  `correct_correct3D.txt` holds the per-angle correction
# (same value applied to all distances, tiled with `np.tile`).

# %%
_c3d_path = f'{path}/{pfile}_/correct_correct3D.txt'
if os.path.exists(_c3d_path):
    raw_3d = np.loadtxt(_c3d_path)[:ntheta, ::-1].astype('float32')
    correct3d_shifts = np.tile(raw_3d[:, np.newaxis], (1, ndist, 1))
else:
    print(f'correct3D not found, using zeros: {_c3d_path}')
    correct3d_shifts = np.zeros([ntheta, ndist, 2], dtype='float32')

# %% [markdown]
# ### Visualization

# %%
show = True  # set False to skip all plots

if show:
    fig, axes = plt.subplots(4, 2, figsize=(12, 10))
    labels = ['motion', 'correct3D', 'rhapp', 'random']
    arrays = [motion_shifts, correct3d_shifts, rhapp_shifts, random_shifts]
    for ax_row, (lbl, arr) in zip(axes, zip(labels, arrays)):
        ax_row[0].plot(arr[:, :, 0]); ax_row[0].set_title(f'{lbl}  row (y)')
        ax_row[1].plot(arr[:, :, 1]); ax_row[1].set_title(f'{lbl}  col (x)')
    plt.tight_layout()
    plt.show()

# %% [markdown]
# #### Final combined shift = encoder + rhapp + motion + 3D correction
#
# All four sources are additive; the result is saved as `/exchange/cshifts_final` (float32,
# shape `[ntheta, ndist, 2]`) for use in Steps 4 and 5.

# %%
shifts_final = rhapp_shifts + correct3d_shifts + motion_shifts + random_shifts

# %% [markdown]
# ## Save to file

# %%
with h5py.File(fpath, 'a') as fid:
    if '/exchange/cshifts_final' in fid:
        del fid['/exchange/cshifts_final']
    fid.create_dataset('/exchange/cshifts_final', data=shifts_final.astype('float32'))

# %%
if show:
    fig, axes = plt.subplots(1, 2, figsize=(12, 4))
    axes[0].plot(shifts_final[:, :, 0]); axes[0].set_title('cshifts_final  row (y)')
    axes[1].plot(shifts_final[:, :, 1]); axes[1].set_title('cshifts_final  col (x)')
    plt.tight_layout()
    plt.show()
