# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %%
from holotomocupy.utils import *

# %%
a = read_tiff(f'//data2/vnikitin/brain_rec/20251115/Y350a/Y350a1234/run3/0/rec_objz/0160.tiff')
b = read_tiff(f'/data2/vnikitin/brain/20251115/Y350a_HT_20nm_8dist_rec1234_/naburec/results/20251122_190427//correct_3D_001024.tiff')
print(a.shape)
print(b.shape)

crop=a.shape[0]//2-b.shape[0]//2
a = a[crop:-crop,crop:-crop]
# b = np.fromfile(f'/data2/vnikitin/brain/20251115/Y350a_HT_20nm_8dist_rec4567_/Y350a_HT_20nm_8dist_rec_cm_.vol', dtype=np.float32)
# b = b.reshape([2048,2486,2486])
# b=b[b.shape[0]//2]
# bb = np.fft.fftshift(np.fft.fft2(np.fft.fftshift(b)))
# mshow(np.log10(np.abs(bb[0])),True)
aa = a[768:1536,768:1536]
bb = b[768:1536,768:1536]
print(aa.shape)
# aaa = a[300:-300,300:-300]
# bbb = b[300:-300,300:-300]
def find_min_max(data):
    """Find min and max values according to histogram"""

    h, e = np.histogram(data[:], 1000)
    stend = np.where(h > np.max(h)*0.03)
    st = stend[0][0]
    end = stend[0][-1]
    mmin = e[st]
    mmax = e[end+1]

    return mmin, mmax
mmin1,mmax1 = find_min_max(aa)
mmin2,mmax2 = find_min_max(bb)
mmin2*=1
mmax2*=1
print(mmin2,mmax2)
aa = (aa-mmin1)/(mmax1-mmin1)
bb = (bb-mmin2)/(mmax2-mmin2)
aa[aa<0] = 0
aa[aa>1] = 1
bb[bb<0] = 0
bb[bb>1] = 1
mshow_complex(aa+1j*bb,True)
write_tiff(aa,'/data2/tmp/rr/a.tiff')
write_tiff(bb,'/data2/tmp/rr/b.tiff')

# %%
# a = read_tiff(f'//data2/vnikitin/brain_rec/20251115/Y350a/Y350a1234/run3/0/rec_obj_real/0160.tiff')[3264//2-1024:-(3264//2-1024),crop:-crop,crop:-crop]
# write_tiff(a,'/data2/vnikitin/brain_rec/20251115/Y350a/Y350a1234/denoising/all_iter160')

# a[:] = read_tiff(f'//data2/vnikitin/brain_rec/20251115/Y350a/Y350a1234/run4/0/rec_obj_real/0160.tiff')[3264//2-1024:-(3264//2-1024),crop:-crop,crop:-crop]
# write_tiff(a,'/data2/vnikitin/brain_rec/20251115/Y350a/Y350a1234/denoising/even_iter160')

# a[:] = read_tiff(f'//data2/vnikitin/brain_rec/20251115/Y350a/Y350a1234/run4/0/rec_obj_real/0160.tiff')[3264//2-1024:-(3264//2-1024),crop:-crop,crop:-crop]
# write_tiff(a,'/data2/vnikitin/brain_rec/20251115/Y350a/Y350a1234/denoising/odd_iter160')


# a[:] = read_tiff(f'//data2/vnikitin/brain_rec/20251115/Y350a/Y350a1234/run3/0/rec_obj_real/0096.tiff')[3264//2-1024:-(3264//2-1024),crop:-crop,crop:-crop]
# write_tiff(a,'/data2/vnikitin/brain_rec/20251115/Y350a/Y350a1234/denoising/all_iter96')

a[:] = read_tiff(f'//data2/vnikitin/brain_rec/20251115/Y350a/Y350a1234/run4/0/rec_obj_real/0096.tiff')[3264//2-1024:-(3264//2-1024),crop:-crop,crop:-crop]
write_tiff(a,'/data2/vnikitin/brain_rec/20251115/Y350a/Y350a1234/denoising/even_iter96')

a[:] = read_tiff(f'//data2/vnikitin/brain_rec/20251115/Y350a/Y350a1234/run4/0/rec_obj_real/0096.tiff')[3264//2-1024:-(3264//2-1024),crop:-crop,crop:-crop]
write_tiff(a,'/data2/vnikitin/brain_rec/20251115/Y350a/Y350a1234/denoising/odd_iter96')
ddd
# a = read_tiff(f'//data2/vnikitin/brain_rec/20251115/Y350a/Y350a1234/run3/0/rec_obj_real/0160.tiff')[3264//2-1024:,-(3264//2-1024):,crop:-crop,crop:-crop]
# write_tiff(a,'/data2/vnikitin/alfred/nobin_even')

# write_tiff(aa,'/data2/vnikitin/alfred/nobin_odd')
# write_tiff(aaa,'/data2/vnikitin/alfred/nobin_all')



# b = np.fromfile(f'/data2/vnikitin/brain/20251115/Y350a_HT_20nm_8dist_rec1234_/Y350a_HT_20nm_8dist_rec_.vol', dtype=np.float32)
# b = b.reshape([2048,3216,3216])
# def find_min_max(data):
#     """Find min and max values according to histogram"""

#     h, e = np.histogram(data[:], 1000)
#     stend = np.where(h > np.max(h)*0.03)
#     st = stend[0][0]
#     end = stend[0][-1]
#     mmin = e[st]
#     mmax = e[end+1]

#     return mmin, mmax
# mmin1,mmax1 = find_min_max(aa)
# mmin2,mmax2 = find_min_max(bb)
# mmin2*=1
# mmax2*=1
# print(mmin2,mmax2)
# aa = (aa-mmin1)/(mmax1-mmin1)
# bb = (bb-mmin2)/(mmax2-mmin2)
# # aa[aa<0] = 0
# # aa[aa>1] = 1
# # bb[bb<0] = 0
# # bb[bb>1] = 1
# mshow_complex(aa+1j*bb,True)
# write_tiff(aa,'/data2/tmp/rr/a.tiff')
# write_tiff(bb,'/data2/tmp/rr/b.tiff')
