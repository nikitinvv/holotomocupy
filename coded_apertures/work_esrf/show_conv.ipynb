# %%
import numpy as np
import cupy as cp
import matplotlib.pyplot as plt

# %%
conv={}
end = 64
for k in ['175', '176', '1765', '177', '1775','178','1785']:
    conv[f'{k}'] = np.load(f'/data2/vnikitin/nfp_codes/conv2048_-0.0{k}.npy')
    plt.plot(conv[f'{k}'][:end],label=f'{k}')
    print(f'{k}',conv[f'{k}'][end])
plt.yscale('log')
plt.legend()
plt.show()
# Out:
# 175 32042.759765625
# 176 30964.5390625
# 1765 30594.0546875
# 177 30343.5546875
# 1775 30216.50390625
# 178 30216.021484375
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[36], line 4
#       2 end = 64
#       3 for k in ['175', '176', '1765', '177', '1775','178','1785']:
# ----> 4     conv[f'{k}'] = np.load(f'/data2/vnikitin/nfp_codes/conv2048_-0.0{k}.npy')
#       5     plt.plot(conv[f'{k}'][:end],label=f'{k}')
#       6     print(f'{k}',conv[f'{k}'][end])
#
# File ~/conda/miniforge3/envs/holotomocupy/lib/python3.12/site-packages/numpy/lib/npyio.py:427, in load(file, mmap_mode, allow_pickle, fix_imports, encoding, max_header_size)
#     425     own_fid = False
#     426 else:
# --> 427     fid = stack.enter_context(open(os_fspath(file), "rb"))
#     428     own_fid = True
#     430 # Code to distinguish from NumPy binary files and pickles.
#
# FileNotFoundError: [Errno 2] No such file or directory: '/data2/vnikitin/nfp_codes/conv2048_-0.01785.npy'
